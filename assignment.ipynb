# %%
import pandas as pd

# %%
# column_names = ['task', 'status', 'trackerID', 'serverregion','timestamp', 'server']
df = pd.read_csv('/Users/adeleke/Desktop/10Alytics/Cohort 7/log.txt', sep='|', names=['task', 'status', 'trackerID', 'serverregion','timestamp', 'server'])

# %%
df.head()
# Out:
#                                      task   status    trackerID  \
# 0                  Data quality assurance  success  89328463487
# 1  Designing and implementing data models  success  89328463488
# 2    Extracting data from various sources  success  89328463489
# 3      Loading data into a data warehouse  success  89328463490
# 4                  Data quality assurance  success  89328463491
#
#            serverregion      timestamp  \
# 0           Florida;USA  1599093305000
# 1        Ontario;Canada  1589218599000
# 2        California;USA  1595463446000
# 3           Florida;USA  1605932487000
# 4  Queensland;Australia  1587354266000
#
#                                     server
# 0    464f:bdbd:1d:535a:2dad:5117:a92f:b359
# 1  1366:c314:8d40:4219:4a51:138f:7ce3:d244
# 2  1ffa:cdd1:7a2b:a7d8:ab00:eada:94b3:7a7c
# 3  8ac5:9010:f24c:2f06:4679:aaec:a737:f003
# 4  5a7d:18ec:4650:5421:185c:4fa0:2e86:6643

# %%
# First split the columns severregion
df[['execution_state', 'execution_country']] = df['serverregion'].str.split(';', expand=True)

# %%
df.head(5)
# Out:
#                                      task   status    trackerID  \
# 0                  Data quality assurance  success  89328463487
# 1  Designing and implementing data models  success  89328463488
# 2    Extracting data from various sources  success  89328463489
# 3      Loading data into a data warehouse  success  89328463490
# 4                  Data quality assurance  success  89328463491
#
#            serverregion      timestamp  \
# 0           Florida;USA  1599093305000
# 1        Ontario;Canada  1589218599000
# 2        California;USA  1595463446000
# 3           Florida;USA  1605932487000
# 4  Queensland;Australia  1587354266000
#
#                                     server execution_state execution_country
# 0    464f:bdbd:1d:535a:2dad:5117:a92f:b359         Florida               USA
# 1  1366:c314:8d40:4219:4a51:138f:7ce3:d244         Ontario            Canada
# 2  1ffa:cdd1:7a2b:a7d8:ab00:eada:94b3:7a7c      California               USA
# 3  8ac5:9010:f24c:2f06:4679:aaec:a737:f003         Florida               USA
# 4  5a7d:18ec:4650:5421:185c:4fa0:2e86:6643      Queensland         Australia

# %%
df
# Out:
#                                        task   status    trackerID  \
# 0                    Data quality assurance  success  89328463487
# 1    Designing and implementing data models  success  89328463488
# 2      Extracting data from various sources  success  89328463489
# 3        Loading data into a data warehouse  success  89328463490
# 4                    Data quality assurance  success  89328463491
# ..                                      ...      ...          ...
# 995                         Data governance  success  89328464482
# 996         Optimizing database performance   failed  89328464483
# 997         Optimizing database performance  success  89328464484
# 998                 Building data pipelines  success  89328464485
# 999  Designing and implementing data models  success  89328464486
#
#              serverregion      timestamp  \
# 0             Florida;USA  1599093305000
# 1          Ontario;Canada  1589218599000
# 2          California;USA  1595463446000
# 3             Florida;USA  1605932487000
# 4    Queensland;Australia  1587354266000
# ..                    ...            ...
# 995             Texas;USA  1593117157000
# 996        California;USA  1597399201000
# 997             Texas;USA  1607161055000
# 998             Texas;USA  1588130663000
# 999          New York;USA  1604987132000
#
#                                       server execution_state execution_country
# 0      464f:bdbd:1d:535a:2dad:5117:a92f:b359         Florida               USA
# 1    1366:c314:8d40:4219:4a51:138f:7ce3:d244         Ontario            Canada
# 2    1ffa:cdd1:7a2b:a7d8:ab00:eada:94b3:7a7c      California               USA
# 3    8ac5:9010:f24c:2f06:4679:aaec:a737:f003         Florida               USA
# 4    5a7d:18ec:4650:5421:185c:4fa0:2e86:6643      Queensland         Australia
# ..                                       ...             ...               ...
# 995  e1b6:24be:69e6:7835:281b:d015:bc04:4150           Texas               USA
# 996   18de:15cb:f964:bc62:491:9d79:da3f:a6fd      California               USA
# 997  cc7c:3591:1c62:280c:b259:dc89:e69d:2d75           Texas               USA
# 998   3336:1461:f197:bad9:705f:7dd:8c59:a5e4           Texas               USA
# 999  633d:e149:e22f:a277:b5f6:dae8:b32c:ea9e        New York               USA
#
# [1000 rows x 8 columns]

# %%
# Then want to rename the columns to depict the description

# %%
df.rename(columns={'task':'executed_task', 'status': 'execution_status', 'trackerID': 'tracker_id', 'serverregion': 'server_region', 'server': 'server_id'}, inplace=True)

# %%
df.head(2)
# Out:
#                             executed_task execution_status   tracker_id  \
# 0                  Data quality assurance          success  89328463487
# 1  Designing and implementing data models          success  89328463488
#
#     server_region      timestamp                                server_id  \
# 0     Florida;USA  1599093305000    464f:bdbd:1d:535a:2dad:5117:a92f:b359
# 1  Ontario;Canada  1589218599000  1366:c314:8d40:4219:4a51:138f:7ce3:d244
#
#   execution_state execution_country
# 0         Florida               USA
# 1         Ontario            Canada

# %%
df.isna().info()
df['tracker_id'].dtype
#df['server_region'].dtype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   executed_task      1000 non-null   bool
#  1   execution_status   1000 non-null   bool
#  2   tracker_id         1000 non-null   bool
#  3   server_region      1000 non-null   bool
#  4   timestamp          1000 non-null   bool
#  5   server_id          1000 non-null   bool
#  6   execution_state    1000 non-null   bool
#  7   execution_country  1000 non-null   bool
# dtypes: bool(8)
# memory usage: 7.9 KB
# dtype('int64')

# %%
# Okay it appears timestamp should be 10 digits, so i'll check how many rows are over 10 digits
list = []
for i in df['timestamp']:
    if len(str(i)) == 13:
        list.append(i)
print(len(list))
# Out:
# 1000

# %%
# So all columns have 13 digits, ill simply slice instead of dividing by 1000, okay its an integer so no slicing
df['timestamp'] = df['timestamp']/1000

# %%
df
# Out:
#                               executed_task execution_status   tracker_id  \
# 0                    Data quality assurance          success  89328463487
# 1    Designing and implementing data models          success  89328463488
# 2      Extracting data from various sources          success  89328463489
# 3        Loading data into a data warehouse          success  89328463490
# 4                    Data quality assurance          success  89328463491
# ..                                      ...              ...          ...
# 995                         Data governance          success  89328464482
# 996         Optimizing database performance           failed  89328464483
# 997         Optimizing database performance          success  89328464484
# 998                 Building data pipelines          success  89328464485
# 999  Designing and implementing data models          success  89328464486
#
#             server_region     timestamp  \
# 0             Florida;USA  1.599093e+09
# 1          Ontario;Canada  1.589219e+09
# 2          California;USA  1.595463e+09
# 3             Florida;USA  1.605932e+09
# 4    Queensland;Australia  1.587354e+09
# ..                    ...           ...
# 995             Texas;USA  1.593117e+09
# 996        California;USA  1.597399e+09
# 997             Texas;USA  1.607161e+09
# 998             Texas;USA  1.588131e+09
# 999          New York;USA  1.604987e+09
#
#                                    server_id execution_state execution_country
# 0      464f:bdbd:1d:535a:2dad:5117:a92f:b359         Florida               USA
# 1    1366:c314:8d40:4219:4a51:138f:7ce3:d244         Ontario            Canada
# 2    1ffa:cdd1:7a2b:a7d8:ab00:eada:94b3:7a7c      California               USA
# 3    8ac5:9010:f24c:2f06:4679:aaec:a737:f003         Florida               USA
# 4    5a7d:18ec:4650:5421:185c:4fa0:2e86:6643      Queensland         Australia
# ..                                       ...             ...               ...
# 995  e1b6:24be:69e6:7835:281b:d015:bc04:4150           Texas               USA
# 996   18de:15cb:f964:bc62:491:9d79:da3f:a6fd      California               USA
# 997  cc7c:3591:1c62:280c:b259:dc89:e69d:2d75           Texas               USA
# 998   3336:1461:f197:bad9:705f:7dd:8c59:a5e4           Texas               USA
# 999  633d:e149:e22f:a277:b5f6:dae8:b32c:ea9e        New York               USA
#
# [1000 rows x 8 columns]

# %%
# Attempt converting timestamp to human readable datetime format
df['execution_date'] = pd.to_datetime(df['timestamp'], unit='s')

# %%
df
# Out:
#                               executed_task execution_status   tracker_id  \
# 0                    Data quality assurance          success  89328463487
# 1    Designing and implementing data models          success  89328463488
# 2      Extracting data from various sources          success  89328463489
# 3        Loading data into a data warehouse          success  89328463490
# 4                    Data quality assurance          success  89328463491
# ..                                      ...              ...          ...
# 995                         Data governance          success  89328464482
# 996         Optimizing database performance           failed  89328464483
# 997         Optimizing database performance          success  89328464484
# 998                 Building data pipelines          success  89328464485
# 999  Designing and implementing data models          success  89328464486
#
#             server_region     timestamp  \
# 0             Florida;USA  1.599093e+09
# 1          Ontario;Canada  1.589219e+09
# 2          California;USA  1.595463e+09
# 3             Florida;USA  1.605932e+09
# 4    Queensland;Australia  1.587354e+09
# ..                    ...           ...
# 995             Texas;USA  1.593117e+09
# 996        California;USA  1.597399e+09
# 997             Texas;USA  1.607161e+09
# 998             Texas;USA  1.588131e+09
# 999          New York;USA  1.604987e+09
#
#                                    server_id execution_state  \
# 0      464f:bdbd:1d:535a:2dad:5117:a92f:b359         Florida
# 1    1366:c314:8d40:4219:4a51:138f:7ce3:d244         Ontario
# 2    1ffa:cdd1:7a2b:a7d8:ab00:eada:94b3:7a7c      California
# 3    8ac5:9010:f24c:2f06:4679:aaec:a737:f003         Florida
# 4    5a7d:18ec:4650:5421:185c:4fa0:2e86:6643      Queensland
# ..                                       ...             ...
# 995  e1b6:24be:69e6:7835:281b:d015:bc04:4150           Texas
# 996   18de:15cb:f964:bc62:491:9d79:da3f:a6fd      California
# 997  cc7c:3591:1c62:280c:b259:dc89:e69d:2d75           Texas
# 998   3336:1461:f197:bad9:705f:7dd:8c59:a5e4           Texas
# 999  633d:e149:e22f:a277:b5f6:dae8:b32c:ea9e        New York
#
#     execution_country      execution_date
# 0                 USA 2020-09-03 00:35:05
# 1              Canada 2020-05-11 17:36:39
# 2                 USA 2020-07-23 00:17:26
# 3                 USA 2020-11-21 04:21:27
# 4           Australia 2020-04-20 03:44:26
# ..                ...                 ...
# 995               USA 2020-06-25 20:32:37
# 996               USA 2020-08-14 10:00:01
# 997               USA 2020-12-05 09:37:35
# 998               USA 2020-04-29 03:24:23
# 999               USA 2020-11-10 05:45:32
#
# [1000 rows x 9 columns]

# %%
df.rename(columns={'server_id': 'server_ip_address', 'timestamp': 'execution_time'}, inplace=True)

# %%
df
# Out:
#                               executed_task execution_status   tracker_id  \
# 0                    Data quality assurance          success  89328463487
# 1    Designing and implementing data models          success  89328463488
# 2      Extracting data from various sources          success  89328463489
# 3        Loading data into a data warehouse          success  89328463490
# 4                    Data quality assurance          success  89328463491
# ..                                      ...              ...          ...
# 995                         Data governance          success  89328464482
# 996         Optimizing database performance           failed  89328464483
# 997         Optimizing database performance          success  89328464484
# 998                 Building data pipelines          success  89328464485
# 999  Designing and implementing data models          success  89328464486
#
#             server_region  execution_time  \
# 0             Florida;USA    1.599093e+09
# 1          Ontario;Canada    1.589219e+09
# 2          California;USA    1.595463e+09
# 3             Florida;USA    1.605932e+09
# 4    Queensland;Australia    1.587354e+09
# ..                    ...             ...
# 995             Texas;USA    1.593117e+09
# 996        California;USA    1.597399e+09
# 997             Texas;USA    1.607161e+09
# 998             Texas;USA    1.588131e+09
# 999          New York;USA    1.604987e+09
#
#                            server_ip_address execution_state  \
# 0      464f:bdbd:1d:535a:2dad:5117:a92f:b359         Florida
# 1    1366:c314:8d40:4219:4a51:138f:7ce3:d244         Ontario
# 2    1ffa:cdd1:7a2b:a7d8:ab00:eada:94b3:7a7c      California
# 3    8ac5:9010:f24c:2f06:4679:aaec:a737:f003         Florida
# 4    5a7d:18ec:4650:5421:185c:4fa0:2e86:6643      Queensland
# ..                                       ...             ...
# 995  e1b6:24be:69e6:7835:281b:d015:bc04:4150           Texas
# 996   18de:15cb:f964:bc62:491:9d79:da3f:a6fd      California
# 997  cc7c:3591:1c62:280c:b259:dc89:e69d:2d75           Texas
# 998   3336:1461:f197:bad9:705f:7dd:8c59:a5e4           Texas
# 999  633d:e149:e22f:a277:b5f6:dae8:b32c:ea9e        New York
#
#     execution_country      execution_date
# 0                 USA 2020-09-03 00:35:05
# 1              Canada 2020-05-11 17:36:39
# 2                 USA 2020-07-23 00:17:26
# 3                 USA 2020-11-21 04:21:27
# 4           Australia 2020-04-20 03:44:26
# ..                ...                 ...
# 995               USA 2020-06-25 20:32:37
# 996               USA 2020-08-14 10:00:01
# 997               USA 2020-12-05 09:37:35
# 998               USA 2020-04-29 03:24:23
# 999               USA 2020-11-10 05:45:32
#
# [1000 rows x 9 columns]

# %%
df['executed_task'].value_counts()
# Out:
# executed_task
# Extracting data from various sources       201
# Data governance                            116
# Data quality assurance                     111
# Loading data into a data warehouse         106
# Building data pipelines                    102
# Transforming data into a unified format    102
# Data integration                           100
# Optimizing database performance             83
# Designing and implementing data models      79
# Name: count, dtype: int64

# %%
df.groupby('execution_status')['tracker_id'].count()
# Out:
# execution_status
# -          113
# failed     121
# success    766
# Name: tracker_id, dtype: int64

# %%
df.loc[(df['execution_status'] != 'failed') & (df['execution_status'] != 'success')]
# Out:
#                               executed_task execution_status   tracker_id  \
# 6           Optimizing database performance                -  89328463493
# 16   Designing and implementing data models                -  89328463503
# 17                   Data quality assurance                -  89328463504
# 31                          Data governance                -  89328463518
# 50     Extracting data from various sources                -  89328463537
# ..                                      ...              ...          ...
# 960         Optimizing database performance                -  89328464447
# 967    Extracting data from various sources                -  89328464454
# 980                 Building data pipelines                -  89328464467
# 989                  Data quality assurance                -  89328464476
# 993                        Data integration                -  89328464480
#
#             server_region  execution_time  \
# 6             Tokyo;Japan    1.596900e+09
# 16              Texas;USA    1.602189e+09
# 17              Texas;USA    1.589043e+09
# 31           Paris;France    1.590871e+09
# 50   Queensland;Australia    1.605309e+09
# ..                    ...             ...
# 960             Texas;USA    1.605748e+09
# 967  Queensland;Australia    1.598299e+09
# 980             Texas;USA    1.596457e+09
# 989           Florida;USA    1.602308e+09
# 993        Ontario;Canada    1.587385e+09
#
#                            server_ip_address execution_state  \
# 6    7f2b:df86:5279:687d:2f43:9cbe:d291:8125           Tokyo
# 16    56c0:efbf:2ecc:67b6:61c:2fa6:7b12:2e12           Texas
# 17   99db:f6af:4b20:e70d:3f70:a3a7:1750:dd48           Texas
# 31    2e0:9665:ad00:a232:ed01:8244:ed87:6e55           Paris
# 50    730a:74b4:cefe:60a:65b4:c024:b7ce:35c4      Queensland
# ..                                       ...             ...
# 960  8a07:4614:ba3f:75ca:816f:66c9:da0d:8a8d           Texas
# 967  1fe1:2555:111d:7219:affb:e177:a079:733a      Queensland
# 980  9416:11fa:1599:e4b4:1976:dc30:c4a5:19c6           Texas
# 989  34ff:463b:f027:af2c:3a96:14c6:faef:b94a         Florida
# 993   9881:ebd9:fcc2:75b:d26e:d0ea:dbfc:131b         Ontario
#
#     execution_country      execution_date
# 6               Japan 2020-08-08 15:23:35
# 16                USA 2020-10-08 20:35:13
# 17                USA 2020-05-09 16:42:47
# 31             France 2020-05-30 20:33:05
# 50          Australia 2020-11-13 23:08:36
# ..                ...                 ...
# 960               USA 2020-11-19 01:11:19
# 967         Australia 2020-08-24 20:01:47
# 980               USA 2020-08-03 12:22:01
# 989               USA 2020-10-10 05:28:41
# 993            Canada 2020-04-20 12:18:57
#
# [113 rows x 9 columns]

# %%
# Changed '-' in status to a meaningful text

# %%
df['execution_status'] = df['execution_status'].apply(lambda text : text.replace('-', 'others'))

# %%
df.loc[(df['execution_status'] != 'failed') & (df['execution_status'] != 'success')]
# Out:
#                               executed_task execution_status   tracker_id  \
# 6           Optimizing database performance           others  89328463493
# 16   Designing and implementing data models           others  89328463503
# 17                   Data quality assurance           others  89328463504
# 31                          Data governance           others  89328463518
# 50     Extracting data from various sources           others  89328463537
# ..                                      ...              ...          ...
# 960         Optimizing database performance           others  89328464447
# 967    Extracting data from various sources           others  89328464454
# 980                 Building data pipelines           others  89328464467
# 989                  Data quality assurance           others  89328464476
# 993                        Data integration           others  89328464480
#
#             server_region  execution_time  \
# 6             Tokyo;Japan    1.596900e+09
# 16              Texas;USA    1.602189e+09
# 17              Texas;USA    1.589043e+09
# 31           Paris;France    1.590871e+09
# 50   Queensland;Australia    1.605309e+09
# ..                    ...             ...
# 960             Texas;USA    1.605748e+09
# 967  Queensland;Australia    1.598299e+09
# 980             Texas;USA    1.596457e+09
# 989           Florida;USA    1.602308e+09
# 993        Ontario;Canada    1.587385e+09
#
#                            server_ip_address execution_state  \
# 6    7f2b:df86:5279:687d:2f43:9cbe:d291:8125           Tokyo
# 16    56c0:efbf:2ecc:67b6:61c:2fa6:7b12:2e12           Texas
# 17   99db:f6af:4b20:e70d:3f70:a3a7:1750:dd48           Texas
# 31    2e0:9665:ad00:a232:ed01:8244:ed87:6e55           Paris
# 50    730a:74b4:cefe:60a:65b4:c024:b7ce:35c4      Queensland
# ..                                       ...             ...
# 960  8a07:4614:ba3f:75ca:816f:66c9:da0d:8a8d           Texas
# 967  1fe1:2555:111d:7219:affb:e177:a079:733a      Queensland
# 980  9416:11fa:1599:e4b4:1976:dc30:c4a5:19c6           Texas
# 989  34ff:463b:f027:af2c:3a96:14c6:faef:b94a         Florida
# 993   9881:ebd9:fcc2:75b:d26e:d0ea:dbfc:131b         Ontario
#
#     execution_country      execution_date
# 6               Japan 2020-08-08 15:23:35
# 16                USA 2020-10-08 20:35:13
# 17                USA 2020-05-09 16:42:47
# 31             France 2020-05-30 20:33:05
# 50          Australia 2020-11-13 23:08:36
# ..                ...                 ...
# 960               USA 2020-11-19 01:11:19
# 967         Australia 2020-08-24 20:01:47
# 980               USA 2020-08-03 12:22:01
# 989               USA 2020-10-10 05:28:41
# 993            Canada 2020-04-20 12:18:57
#
# [113 rows x 9 columns]
